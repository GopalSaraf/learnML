# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([[2104, 5, 1, 45], [1416, 3, 2, 40], [852, 2, 1, 35]])
y = np.array([460, 232, 178])

# %%
from learnML.regression import LinearRegression

model = LinearRegression(learning_rate=10.0e-10, n_iterations=1000)
model.fit(X, y)
# Out:
# Iteration:     0 | Cost: 4.928516e+04
# Iteration:   100 | Cost: 3.082082e+04
# Iteration:   200 | Cost: 1.937326e+04
# Iteration:   300 | Cost: 1.227597e+04
# Iteration:   400 | Cost: 7.875782e+03
# Iteration:   500 | Cost: 5.147742e+03
# Iteration:   600 | Cost: 3.456405e+03
# Iteration:   700 | Cost: 2.407805e+03
# Iteration:   800 | Cost: 1.757691e+03
# Iteration:   900 | Cost: 1.354631e+03
# Iteration:  1000 | Cost: 1.106694e+03

# %%
print(f"After training: w = {model.get_weights()}, b = {model.get_intercept()}")
# Out:
# After training: w = [1.83651522e-01 4.29213491e-04 1.25524261e-04 4.50255798e-03], b = 0.00010734897166877989

# %%
X_test = np.array([[2104, 5, 1, 45]])
y_pred = model.predict(X_test)

print(f"Prediction for {X_test} : {y_pred[0]}")
# Out:
# Prediction for [[2104    5    1   45]] : 386.6077953283248

# %%
plt.plot(model.get_cost_history())
plt.title("Cost vs. iteration")
plt.ylabel("Cost")
plt.xlabel("iteration step")
plt.show()
